# %%
import pandas as pd
import numpy as np
import seaborn as sbn

# %%
df_fifa = pd.read_csv("fifaplayers_pt.csv")

# %%
df_fifa.head()
# Out:
#        id               nome  idade nacionalidade  pontuação geral  potencial  \
# 0  158023           L. Messi     31     Argentina               94         94
# 1   20801  Cristiano Ronaldo     33      Portugal               94         94
# 2  190871          Neymar Jr     26        Brazil               92         93
# 3  193080             De Gea     27         Spain               91         93
# 4  192985       K. De Bruyne     27       Belgium               91         92
#
#                   time    valor remuneração perna de preferência  ...  \
# 0         FC Barcelona  €110.5M       €565K             Esquerda  ...
# 1             Juventus     €77M       €405K              Direita  ...
# 2  Paris Saint-Germain  €118.5M       €290K              Direita  ...
# 3    Manchester United     €72M       €260K              Direita  ...
# 4      Manchester City    €102M       €355K              Direita  ...
#
#    emprestado de  validade do contrato  altura    peso controle de bola  \
# ...

# %%
df_fifa.tail()
# Out:
#            id                nome  idade nacionalidade  pontuação geral  \
# 18202  238813        J. Lundstram     19       England               47
# 18203  243165  N. Christoffersson     19        Sweden               47
# 18204  241638           B. Worman     16       England               47
# 18205  246268      D. Walker-Rice     17       England               47
# 18206  246269           G. Nugent     16       England               46
#
#        potencial              time valor remuneração perna de preferência  \
# 18202         65   Crewe Alexandra  €60K         €1K              Direita
# 18203         63    Trelleborgs FF  €60K         €1K              Direita
# 18204         67  Cambridge United  €60K         €1K              Direita
# 18205         66   Tranmere Rovers  €60K         €1K              Direita
# 18206         66   Tranmere Rovers  €60K         €1K              Direita
#
#        ...  emprestado de  validade do contrato  altura    peso  \
# ...

# %%
df_fifa.columns = ['id', 'nome', 'idade', 'nacionalidade', 'pontuacao_geral', 'potencial',
       'time', 'valor', 'remuneracao', 'perna_preferencia',
       'reputaçao_internacional', 'posição', 'camisa', 'contratacao',
       'emprestado_de', 'validade_contrato', 'altura', 'peso',
       'controle_bola', 'arrancada', 'agilidade', 'equilibrio', 'energia',
       'força']

# %%
df_fifa.set_index("id", inplace=True)

# %%
df_fifa
# Out:
#            id                nome  idade nacionalidade  pontuacao_geral  \
# 0      158023            L. Messi     31     Argentina               94
# 1       20801   Cristiano Ronaldo     33      Portugal               94
# 2      190871           Neymar Jr     26        Brazil               92
# 3      193080              De Gea     27         Spain               91
# 4      192985        K. De Bruyne     27       Belgium               91
# ...       ...                 ...    ...           ...              ...
# 18202  238813        J. Lundstram     19       England               47
# 18203  243165  N. Christoffersson     19        Sweden               47
# 18204  241638           B. Worman     16       England               47
# 18205  246268      D. Walker-Rice     17       England               47
# 18206  246269           G. Nugent     16       England               46
#
#        potencial                 time    valor remuneracao perna_preferencia  \
# ...

# %% [markdown]
# ## Quantos jogadores tem nacionalidade Argentina
# Resposta: 937 Jogadores

# %%
df_nacionalidade_argentina = df_fifa.loc[df_fifa['nacionalidade'] == "Argentina"]

# %%
df_nacionalidade_argentina.head()
# Out:
#         id        nome  idade nacionalidade  pontuacao_geral  potencial  \
# 0   158023    L. Messi     31     Argentina               94         94
# 15  211110   P. Dybala     24     Argentina               89         94
# 23  153079   S. Agüero     30     Argentina               89         89
# 38  167664  G. Higuaín     30     Argentina               88         88
# 43  201399   M. Icardi     25     Argentina               87         90
#
#                time    valor remuneracao perna_preferencia  ...  \
# 0      FC Barcelona  €110.5M       €565K          Esquerda  ...
# 15         Juventus     €89M       €205K          Esquerda  ...
# 23  Manchester City   €64.5M       €300K           Direita  ...
# 38            Milan     €57M       €245K           Direita  ...
# 43            Inter   €64.5M       €130K           Direita  ...
#
#     emprestado_de validade_contrato  altura    peso controle_bola arrancada  \
# ...

# %%
df_nacionalidade_argentina['nacionalidade'].value_counts()
# Out:
# Argentina    937
# Name: nacionalidade, dtype: int64

# %% [markdown]
# # Quantos Jogadores Brasileiros jogam no Barcelona?
# Resposta: 4 jogadores Brasileiro que jogam no Barcelona

# %%
df_fifa.head()
# Out:
#                      nome  idade nacionalidade  pontuacao_geral  potencial  \
# id
# 158023           L. Messi     31     Argentina               94         94
# 20801   Cristiano Ronaldo     33      Portugal               94         94
# 190871          Neymar Jr     26        Brazil               92         93
# 193080             De Gea     27         Spain               91         93
# 192985       K. De Bruyne     27       Belgium               91         92
#
#                        time    valor remuneração perna_preferencia  \
# id
# 158023         FC Barcelona  €110.5M       €565K          Esquerda
# 20801              Juventus     €77M       €405K           Direita
# 190871  Paris Saint-Germain  €118.5M       €290K           Direita
# 193080    Manchester United     €72M       €260K           Direita
# 192985      Manchester City    €102M       €355K           Direita
#
#         reputaçao_internacional  ... emprestado_de  validade_contrato altura  \
# ...

# %%
df_fifa.query('nacionalidade == "Brazil" & time == "FC Barcelona"')
# Out:
#             nome  idade nacionalidade  pontuacao_geral  potencial  \
# id
# 189242  Coutinho     26        Brazil               88         89
# 230658    Arthur     21        Brazil               82         90
# 222737    Malcom     21        Brazil               82         89
# 201400   Rafinha     25        Brazil               82         87
#
#                 time   valor remuneração perna_preferencia  \
# id
# 189242  FC Barcelona  €69.5M       €340K           Direita
# 230658  FC Barcelona  €32.5M       €125K           Direita
# 222737  FC Barcelona  €31.5M       €140K          Esquerda
# 201400  FC Barcelona  €29.5M       €165K          Esquerda
#
#         reputaçao_internacional  ... emprestado_de  validade_contrato altura  \
# id                               ...
# 189242                      3.0  ...           NaN               2023    5'8
# 230658                      1.0  ...           NaN               2024    5'7
# ...

# %%
df_fifa.query('nacionalidade == "Brazil" & time == "FC Barcelona"')
# Out:
#             nome  idade nacionalidade  pontuacao_geral  potencial  \
# id
# 189242  Coutinho     26        Brazil               88         89
# 230658    Arthur     21        Brazil               82         90
# 222737    Malcom     21        Brazil               82         89
# 201400   Rafinha     25        Brazil               82         87
#
#                 time   valor remuneração perna_preferencia  \
# id
# 189242  FC Barcelona  €69.5M       €340K           Direita
# 230658  FC Barcelona  €32.5M       €125K           Direita
# 222737  FC Barcelona  €31.5M       €140K          Esquerda
# 201400  FC Barcelona  €29.5M       €165K          Esquerda
#
#         reputaçao_internacional  ... emprestado_de  validade_contrato altura  \
# id                               ...
# 189242                      3.0  ...           NaN               2023    5'8
# 230658                      1.0  ...           NaN               2024    5'7
# ...

# %% [markdown]
# ## Qual é a média de idade dos jogadores nascidos no Brasil
# Resposta : 27.62 anos

# %%
df_nacionalidade_brasil = df_fifa.query('nacionalidade == "Brazil"')

# %%
df_nacionalidade_brasil.groupby("nacionalidade").agg({
   'idade' : np.mean
     
})
# Out:
#                    idade
# nacionalidade
# Brazil         27.625151

# %% [markdown]
# ## Qual é o Pais com Maior número de jogadores em Clubes
# Resposta: England

# %%
df_fifa.head()
# Out:
#        id               nome  idade nacionalidade  pontuacao_geral  potencial  \
# 0  158023           L. Messi     31     Argentina               94         94
# 1   20801  Cristiano Ronaldo     33      Portugal               94         94
# 2  190871          Neymar Jr     26        Brazil               92         93
# 3  193080             De Gea     27         Spain               91         93
# 4  192985       K. De Bruyne     27       Belgium               91         92
#
#                   time    valor remuneracao perna_preferencia  ...  \
# 0         FC Barcelona  €110.5M       €565K          Esquerda  ...
# 1             Juventus     €77M       €405K           Direita  ...
# 2  Paris Saint-Germain  €118.5M       €290K           Direita  ...
# 3    Manchester United     €72M       €260K           Direita  ...
# 4      Manchester City    €102M       €355K           Direita  ...
#
#    emprestado_de validade_contrato  altura    peso controle_bola arrancada  \
# ...

# %%
df_fifa['nacionalidade'].value_counts()

# %%
# Out:
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# New Caledonia              1
# Fiji                       1
# São Tomé & Príncipe        1
# United Arab Emirates       1
# Botswana                   1
# Name: nacionalidade, Length: 164, dtype: int64
